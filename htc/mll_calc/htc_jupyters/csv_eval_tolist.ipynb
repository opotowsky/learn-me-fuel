# %%
import ast
import pandas as pd

# %%
spaces = pd.read_csv('../test.csv')
quotes = pd.read_csv('../test_quotes.csv')

# %%
spaces
# Out:
#                                                                                                                   Unnamed: 0  \
# 0 9051 pwr 0.00055 2.0 2107.03 vver1000 9059 pwr 0.0 2.0 2107.03 vver1000 81.146085 0.005383 [81.14608528547559    79.911558
#
#                                                                                                                    sim_idx  \
# 0 9051 pwr 0.00055 2.0 2107.03 vver1000 9059 pwr 0.0 2.0 2107.03 vver1000 81.146085 0.005383 [81.14608528547559   79.20184
#
#                                                                                                                   ReactorType  \
# 0 9051 pwr 0.00055 2.0 2107.03 vver1000 9059 pwr 0.0 2.0 2107.03 vver1000 81.146085 0.005383 [81.14608528547559     73.722295
#
#                                                                                                                   CoolingTime  \
# ...

# %%
quotes
# Out:
#    Unnamed: 0  sim_idx ReactorType  CoolingTime  Enrichment   Burnup  \
# 0           0     9051         pwr      0.00055         2.0  2107.03
#
#   OrigenReactor  pred_idx pred_ReactorType  pred_CoolingTime  pred_Enrichment  \
# 0      vver1000      9059              pwr               0.0              2.0
#
#    pred_Burnup pred_OrigenReactor  LogLL_0.05  LLUnc_0.05  \
# 0      2107.03           vver1000   81.146085    0.005383
#
#                                       CDF_LogLL_0.05  \
# 0  [81.14608528547559, 79.91155802948983, 79.2018...
#
#                                       CDF_LLUnc_0.05
# 0  [0.005383118403588721, 2.0413802145980395, 193...

# %%
check_list = ast.literal_eval(quotes.loc[0, 'CDF_LogLL_0.05'])

# %%
check_list
# Out:
# [81.14608528547559,
#  79.91155802948983,
#  79.20183975252147,
#  73.72229469772951,
#  68.24875983257685,
#  -1560.5363315943177,
#  -2487.585935991207,
#  -2648.736796392991,
#  -736466.3175425312]

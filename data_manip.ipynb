# %%
from training_set import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics
import numpy as np
import pandas as pd
import glob
import os
import posixpath

# %% [markdown]
# # Training Set -> Dataframes

# %% [markdown]
# ### Getting list of files

# %%
train_files = []
datapath = "../origen/origen-data/30nov2017_actinides/"
#datapath = "../origen-data/30nov2017_actinides/"
for i in range(0, len(O_RXTRS)):
    o_rxtr = O_RXTRS[i]
    for j in range(0, len(ENRICH[i])):
        enrich = ENRICH[i][j]
        rxtrpath = datapath + o_rxtr + "/"
        csv = o_rxtr + "_enr" + str(enrich) + "_nucs.csv"
        trainpath = os.path.join(rxtrpath, csv)
        train_files.append(trainpath)
        #print(trainpath)
        #train_files = glob.glob(trainpath)
        #print(train_files)
#train_files = [f.replace("\\", "/") for f in train_files]

# %% [markdown]
# ### Supporting Functions

# %%
def loop_labels(data, burnup, cooling):
    num_cases = NUM_CYCLES
    steps_per_case = len(COOLING_INTERVALS) + 1
    burnup_list = [0, ]
    cooling_list = [0, ]
    for case in range(0, num_cases):
        for step in range(0, steps_per_case):
            if (case == 0 and step == 0):
                continue
            elif (case > 0 and step == 0):
                burnup_list.append(burnup[case-1])
                cooling_list.append(0)
            else:
                burnup_list.append(burnup[case])
                cooling_list.append(COOLING_INTERVALS[step-1])
    return burnup_list, cooling_list

def label_data(labels, data):
    col = len(data.columns)
    enrichments = labels['Enrichment']
    for enrich in enrichments:
        data.insert(loc = col, column = 'ReactorType', value = labels['ReactorType'])
        data.insert(loc = col+1, column = 'Enrichment', value = enrich)
        burnup, cooling_ints = loop_labels(data, labels['Burnup'], labels['CoolingInts'])
        data.insert(loc = col+2, column = 'Burnup', value = burnup)
        data.insert(loc = col+3, column = 'CoolingTime', value = cooling_ints)
    return data

def format_df(filename):
    data = pd.read_csv(filename, header=5, index_col=0).T
    data.drop_duplicates(inplace=True)
    data.drop('subtotal', axis=1, inplace=True)
    return data

# %%
TRAIN_LABELS
# Out:
# {'Burnup': ((3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (3000,
#    6000,
#    9000,
#    12000,
#    15000,
#    18000,
#    21000,
#    24000,
#    27000,
#    30000,
#    33000,
#    36000,
#    39000,
#    42000,
#    45000,
#    48000,
#    51000,
#    54000,
#    57000,
#    60000,
#    63000),
#   (500,
#    1000,
#    1500,
#    2000,
#    2500,
#    3000,
#    3500,
#    4000,
#    4500,
#    5000,
#    5500,
#    6000,
#    6500,
#    7000,
#    7500,
#    8000,
#    8500,
#    9000,
#    9500,
#    10000,
#    10500),
#   (500,
#    1000,
#    1500,
#    2000,
#    2500,
#    3000,
#    3500,
#    4000,
#    4500,
#    5000,
#    5500,
#    6000,
#    6500,
#    7000,
#    7500,
#    8000,
#    8500,
#    9000,
#    9500,
#    10000,
#    10500),
#   (500,
#    1000,
#    1500,
#    2000,
#    2500,
#    3000,
#    3500,
#    4000,
#    4500,
#    5000,
#    5500,
#    6000,
#    6500,
#    7000,
#    7500,
#    8000,
#    8500,
#    9000,
#    9500,
#    10000,
#    10500)),
#  'Enrichment': ((1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (2.4, 3.6),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (1.5, 3.0, 4.0, 5.0),
#   (0.711,),
#   (0.711,),
#   (0.711,)),
#  'OrigenReactor': ('ce14x14',
#   'ce16x16',
#   'w14x14',
#   'w15x15',
#   'w17x17',
#   's14x14',
#   's18x18',
#   'bw15x15',
#   'vver440',
#   'vver1000',
#   'ge7x7-0',
#   'ge8x8-1',
#   'ge9x9-2',
#   'ge10x10-8',
#   'abb8x8-1',
#   'atrium9x9-9',
#   'atrium10x10-9',
#   'svea64-1',
#   'svea100-0',
#   'candu19',
#   'candu28',
#   'candu37'),
#  'ReactorType': ('pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'pwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'bwr',
#   'phwr',
#   'phwr',
#   'phwr')}

# %% [markdown]
# ### Main formatting function

# %%
def dataframeXY(all_files):
    all_data = []
    for f in all_files:
        #issue is that f is already enr dependent but the label has all 1, 2, or 4 enrichments in a list
        idx = all_files.index(f)
        data = format_df(f)
        labels = {'ReactorType': TRAIN_LABELS['ReactorType'][idx],
                  'OrigenReactor': TRAIN_LABELS['OrigenReactor'][idx],
                  'Enrichment': TRAIN_LABELS['Enrichment'][idx], 
                  'Burnup': TRAIN_LABELS['Burnup'][idx], 
                  'CoolingInts': COOLING_INTERVALS
                  }
        labeled = label_data(labels, data)
        all_data.append(labeled)
    dfXY = pd.concat(all_data)
    return dfXY

trainXY = dataframeXY(train_files)
data.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6aa6b693f796> in <module>()
#      15     return dfXY
#      16
# ---> 17 trainXY = dataframeXY(train_files)
#      18 data.head(20)
#
# <ipython-input-4-6aa6b693f796> in dataframeXY(all_files)
#      10                   'CoolingInts': COOLING_INTERVALS
#      11                   }
# ---> 12         labeled = label_data(labels, data)
#      13         all_data.append(labeled)
#      14     dfXY = pd.concat(all_data)
#
# <ipython-input-3-ac580e5439c7> in label_data(labels, data)
#      23         data.insert(loc = col+1, column = 'Enrichment', value = enrich)
#      24         burnup, cooling_ints = loop_labels(data, labels['Burnup'], labels['CoolingInts'])
# ---> 25         data.insert(loc = col+2, column = 'Burnup', value = burnup)
#      26         data.insert(loc = col+3, column = 'CoolingTime', value = cooling_ints)
#      27     return data
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2388         """
#    2389         self._ensure_valid_index(value)
# -> 2390         value = self._sanitize_column(column, value)
#    2391         self._data.insert(
#    2392             loc, column, value, allow_duplicates=allow_duplicates)
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value)
#    2522
#    2523             # turn me into an ndarray
# -> 2524             value = _sanitize_index(value, self.index, copy=False)
#    2525             if not isinstance(value, (np.ndarray, Index)):
#    2526                 if isinstance(value, list) and len(value) > 0:
#
# /usr/lib/python3/dist-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    2739
#    2740     if len(data) != len(index):
# -> 2741         raise ValueError('Length of values does not match length of '
#    2742                          'index')
#    2743
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# ### Split into different Y's for separate ML models

# %%
def splitXY(dfXY):
    x = len(dfXY.columns)-3
    y = x
    # Need better way to know when the nuclide columns start (6 for now)
    # Prob will just search for column idx that starts with str(1)?
    dfX = dfXY.iloc[:, 6:x]
    r_dfY = dfXY.iloc[:, y]
    e_dfY = dfXY.iloc[:, y+1]
    b_dfY = dfXY.iloc[:, y+2]
    return dfX, r_dfY, e_dfY, b_dfY

# %%
trainXY.reset_index(inplace=True)
trainX, r_trainY, e_trainY, b_trainY = splitXY(trainXY)
